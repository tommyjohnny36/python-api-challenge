# %% [markdown]
# # Analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import weather_api_key, g_key
temp_units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# Save as a csv


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# # Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nYour Data Has Been Retrieved\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | killybegs
# Processing Record 2 of Set 1 | tarsus
# Processing Record 3 of Set 1 | japura
# Processing Record 4 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | komsomolskiy
# Processing Record 7 of Set 1 | waldkirchen
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | mackenzie
# Processing Record 12 of Set 1 | carlos antonio lopez
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | karachi
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | dunmore town
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | raudeberg
# Processing Record 26 of Set 1 | dali
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | ifanadiana
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | east london
# City not found. Skipping...
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | leningradskiy
# Processing Record 34 of Set 1 | san rafael
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | gimli
# City not found. Skipping...
# Processing Record 37 of Set 1 | vao
# Processing Record 38 of Set 1 | kango
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | baiyin
# Processing Record 42 of Set 1 | benghazi
# Processing Record 43 of Set 1 | dickinson
# Processing Record 44 of Set 1 | voznesenye
# Processing Record 45 of Set 1 | cordoba
# Processing Record 46 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | bulgan
# Processing Record 3 of Set 2 | zhuzhou
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | naze
# City not found. Skipping...
# Processing Record 6 of Set 2 | djenne
# Processing Record 7 of Set 2 | shimoda
# Processing Record 8 of Set 2 | beloha
# City not found. Skipping...
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | guerrero negro
# Processing Record 11 of Set 2 | lulea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 2 | butaritari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 2 | ankang
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | atherton
# Processing Record 17 of Set 2 | wanning
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | narsaq
# Processing Record 22 of Set 2 | minsk
# Processing Record 23 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | lagos
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 2 | alta floresta
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | villa de cura
# Processing Record 32 of Set 2 | ayan
# Processing Record 33 of Set 2 | buala
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | dunedin
# Processing Record 36 of Set 2 | abu zabad
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | puerto ayacucho
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | vanimo
# Processing Record 46 of Set 2 | sao gabriel da cachoeira
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | faanui
# City not found. Skipping...
# Processing Record 1 of Set 3 | tuburan
# City not found. Skipping...
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | makhu
# Processing Record 5 of Set 3 | saint-denis
# Processing Record 6 of Set 3 | atar
# Processing Record 7 of Set 3 | lodja
# Processing Record 8 of Set 3 | bima
# Processing Record 9 of Set 3 | pitogo
# Processing Record 10 of Set 3 | lisakovsk
# Processing Record 11 of Set 3 | brest
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | banepa
# Processing Record 14 of Set 3 | mugumu
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | labuhan
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | pueblo nuevo
# Processing Record 19 of Set 3 | rexburg
# Processing Record 20 of Set 3 | puerto escondido
# Processing Record 21 of Set 3 | mys shmidta
# Processing Record 22 of Set 3 | koulikoro
# Processing Record 23 of Set 3 | new norfolk
# City not found. Skipping...
# Processing Record 24 of Set 3 | ola
# Processing Record 25 of Set 3 | khromtau
# Processing Record 26 of Set 3 | hambantota
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | san patricio
# City not found. Skipping...
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | havre-saint-pierre
# Processing Record 33 of Set 3 | rusape
# Processing Record 34 of Set 3 | kharabali
# City not found. Skipping...
# Processing Record 35 of Set 3 | araouane
# Processing Record 36 of Set 3 | kununurra
# Processing Record 37 of Set 3 | morshyn
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | floro
# Processing Record 40 of Set 3 | vostok
# Processing Record 41 of Set 3 | sale
# Processing Record 42 of Set 3 | genc
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | visnes
# City not found. Skipping...
# Processing Record 45 of Set 3 | touros
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | nelson bay
# City not found. Skipping...
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | litoral del san juan
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | beni suef
# Processing Record 3 of Set 4 | nizwa
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | khani
# Processing Record 6 of Set 4 | bhinga
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | mbini
# City not found. Skipping...
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | noyabrsk
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | impfondo
# City not found. Skipping...
# Processing Record 13 of Set 4 | coquimbo
# Processing Record 14 of Set 4 | daru
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | chilca
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | rio gallegos
# Processing Record 19 of Set 4 | alamogordo
# Processing Record 20 of Set 4 | marfino
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | castro
# Processing Record 23 of Set 4 | phan thiet
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | grand river south east
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | marshfield
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | taveta
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | montrose
# Processing Record 32 of Set 4 | college
# Processing Record 33 of Set 4 | hobart
# Processing Record 34 of Set 4 | hervey bay
# Processing Record 35 of Set 4 | iskilip
# Processing Record 36 of Set 4 | awbari
# Processing Record 37 of Set 4 | saint-joseph
# Processing Record 38 of Set 4 | akhisar
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | pundaguitan
# Processing Record 41 of Set 4 | gongzhuling
# Processing Record 42 of Set 4 | taoudenni
# Processing Record 43 of Set 4 | aligudarz
# Processing Record 44 of Set 4 | dingle
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | beira
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | san policarpo
# Processing Record 49 of Set 4 | aksu
# Processing Record 1 of Set 5 | gayny
# City not found. Skipping...
# Processing Record 2 of Set 5 | gambiran
# Processing Record 3 of Set 5 | puerto penasco
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | haines junction
# Processing Record 6 of Set 5 | monrovia
# Processing Record 7 of Set 5 | praia
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | hamilton
# Processing Record 10 of Set 5 | iberia
# Processing Record 11 of Set 5 | sulphur
# City not found. Skipping...
# Processing Record 12 of Set 5 | fairlie
# Processing Record 13 of Set 5 | padang
# Processing Record 14 of Set 5 | kamiiso
# Processing Record 15 of Set 5 | mersing
# Processing Record 16 of Set 5 | ivybridge
# Processing Record 17 of Set 5 | roebourne
# Processing Record 18 of Set 5 | severo-kurilsk
# Processing Record 19 of Set 5 | tibati
# Processing Record 20 of Set 5 | gbarnga
# Processing Record 21 of Set 5 | nantucket
# Processing Record 22 of Set 5 | ahuimanu
# Processing Record 23 of Set 5 | norrtalje
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | atasu
# Processing Record 26 of Set 5 | sanming
# Processing Record 27 of Set 5 | nuuk
# Processing Record 28 of Set 5 | chicama
# Processing Record 29 of Set 5 | salekhard
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | iranshahr
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 5 | nogales
# Processing Record 33 of Set 5 | pine bluff
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | luoyang
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | vanavara
# Processing Record 38 of Set 5 | ust-kuyga
# Processing Record 39 of Set 5 | belawan
# Processing Record 40 of Set 5 | cockburn harbour
# Processing Record 41 of Set 5 | jiupu
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | mezen
# Processing Record 44 of Set 5 | tuy hoa
# Processing Record 45 of Set 5 | kudat
# Processing Record 46 of Set 5 | maumere
# City not found. Skipping...
# Processing Record 47 of Set 5 | oda
# Processing Record 48 of Set 5 | san luis
# City not found. Skipping...
# Processing Record 49 of Set 5 | kedougou
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | shostka
# Processing Record 3 of Set 6 | kandrian
# Processing Record 4 of Set 6 | wukari
# Processing Record 5 of Set 6 | benjamin aceval
# Processing Record 6 of Set 6 | alice town
# City not found. Skipping...
# Processing Record 7 of Set 6 | biak
# Processing Record 8 of Set 6 | kutum
# City not found. Skipping...
# Processing Record 9 of Set 6 | dongying
# Processing Record 10 of Set 6 | samagaltay
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | cozumel
# Processing Record 13 of Set 6 | george town
# Processing Record 14 of Set 6 | lozna
# Processing Record 15 of Set 6 | sioux lookout
# Processing Record 16 of Set 6 | inta
# Processing Record 17 of Set 6 | uptar
# Processing Record 18 of Set 6 | henderson
# Processing Record 19 of Set 6 | bowen
# Processing Record 20 of Set 6 | boyuibe
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | chokurdakh
# Processing Record 23 of Set 6 | tracy
# Processing Record 24 of Set 6 | avera
# Processing Record 25 of Set 6 | homer
# City not found. Skipping...
# Processing Record 26 of Set 6 | lovozero
# Processing Record 27 of Set 6 | vila franca do campo
# Processing Record 28 of Set 6 | oktyabrskoye
# Processing Record 29 of Set 6 | bethel
# Processing Record 30 of Set 6 | tingi
# Processing Record 31 of Set 6 | ushtobe
# Processing Record 32 of Set 6 | khotyn
# Processing Record 33 of Set 6 | imeni poliny osipenko
# Processing Record 34 of Set 6 | kismayo
# Processing Record 35 of Set 6 | anadyr
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | waipawa
# Processing Record 38 of Set 6 | shache
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | kitakata
# Processing Record 41 of Set 6 | bjornevatn
# Processing Record 42 of Set 6 | sawtell
# Processing Record 43 of Set 6 | moron
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | rath
# Processing Record 46 of Set 6 | noumea
# Processing Record 47 of Set 6 | bonoua
# Processing Record 48 of Set 6 | biskamzha
# Processing Record 49 of Set 6 | goderich
# Processing Record 1 of Set 7 | gander
# Processing Record 2 of Set 7 | evensk
# City not found. Skipping...
# Processing Record 3 of Set 7 | saint-prosper
# Processing Record 4 of Set 7 | puerto leguizamo
# Processing Record 5 of Set 7 | bambanglipuro
# Processing Record 6 of Set 7 | grand gaube
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | kimbe
# Processing Record 10 of Set 7 | santo antonio do ica
# Processing Record 11 of Set 7 | lamu
# Processing Record 12 of Set 7 | epe
# Processing Record 13 of Set 7 | palmer
# Processing Record 14 of Set 7 | ambilobe
# Processing Record 15 of Set 7 | andros town
# Processing Record 16 of Set 7 | kashi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 7 | ust-koksa
# Processing Record 18 of Set 7 | san antonio
# Processing Record 19 of Set 7 | mattru
# Processing Record 20 of Set 7 | juchitlan
# Processing Record 21 of Set 7 | sylva
# Processing Record 22 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | panalingaan
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | jiaocheng
# Processing Record 27 of Set 7 | muisne
# Processing Record 28 of Set 7 | port lincoln
# Processing Record 29 of Set 7 | paita
# Processing Record 30 of Set 7 | konya
# Processing Record 31 of Set 7 | port antonio
# Processing Record 32 of Set 7 | yaroslavskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | onguday
# Processing Record 34 of Set 7 | tumaco
# Processing Record 35 of Set 7 | coatzintla
# Processing Record 36 of Set 7 | ucluelet
# Processing Record 37 of Set 7 | celestun
# Processing Record 38 of Set 7 | rafaela
# Processing Record 39 of Set 7 | itaituba
# Processing Record 40 of Set 7 | nushki
# Processing Record 41 of Set 7 | puerto colombia
# Processing Record 42 of Set 7 | mazyr
# Processing Record 43 of Set 7 | grindavik
# Processing Record 44 of Set 7 | severo-yeniseyskiy
# Processing Record 45 of Set 7 | svodin
# Processing Record 46 of Set 7 | ryotsu
# Processing Record 47 of Set 7 | tomohon
# Processing Record 48 of Set 7 | nabire
# Processing Record 49 of Set 7 | rocha
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | scarborough
# Processing Record 4 of Set 8 | erzin
# Processing Record 5 of Set 8 | hunchun
# Processing Record 6 of Set 8 | qaqortoq
# Processing Record 7 of Set 8 | kachhwa
# Processing Record 8 of Set 8 | arlit
# Processing Record 9 of Set 8 | penzance
# Processing Record 10 of Set 8 | varhaug
# Processing Record 11 of Set 8 | aklavik
# Processing Record 12 of Set 8 | gaya
# Processing Record 13 of Set 8 | aswan
# Processing Record 14 of Set 8 | marsaxlokk
# Processing Record 15 of Set 8 | oktyabrskiy
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | tashtyp
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | troitskoye
# Processing Record 20 of Set 8 | tupik
# Processing Record 21 of Set 8 | kuytun
# Processing Record 22 of Set 8 | talnakh
# City not found. Skipping...
# Processing Record 23 of Set 8 | panjab
# Processing Record 24 of Set 8 | igarka
# Processing Record 25 of Set 8 | hami
# Processing Record 26 of Set 8 | blackfoot
# Processing Record 27 of Set 8 | damietta
# Processing Record 28 of Set 8 | deder
# Processing Record 29 of Set 8 | senador jose porfirio
# Processing Record 30 of Set 8 | amet
# Processing Record 31 of Set 8 | rakai
# City not found. Skipping...
# Processing Record 32 of Set 8 | pasni
# Processing Record 33 of Set 8 | roald
# Processing Record 34 of Set 8 | santa maria
# Processing Record 35 of Set 8 | bur gabo
# Processing Record 36 of Set 8 | loviisa
# Processing Record 37 of Set 8 | birjand
# Processing Record 38 of Set 8 | valparaiso
# Processing Record 39 of Set 8 | kedrovyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | amuntai
# Processing Record 41 of Set 8 | mmabatho
# Processing Record 42 of Set 8 | shu
# Processing Record 43 of Set 8 | xuanhua
# Processing Record 44 of Set 8 | reconquista
# Processing Record 45 of Set 8 | guapore
# Processing Record 46 of Set 8 | deputatskiy
# Processing Record 47 of Set 8 | tura
# Processing Record 48 of Set 8 | olafsvik
# Processing Record 49 of Set 8 | luwuk
# Processing Record 1 of Set 9 | alugan
# Processing Record 2 of Set 9 | fairbanks
# Processing Record 3 of Set 9 | pitsunda
# Processing Record 4 of Set 9 | kilindoni
# Processing Record 5 of Set 9 | teguldet
# Processing Record 6 of Set 9 | tiznit
# Processing Record 7 of Set 9 | port hardy
# Processing Record 8 of Set 9 | brigantine
# Processing Record 9 of Set 9 | yulara
# Processing Record 10 of Set 9 | ormara
# Processing Record 11 of Set 9 | port macquarie
# Processing Record 12 of Set 9 | margate
# Processing Record 13 of Set 9 | emba
# Processing Record 14 of Set 9 | sawakin
# Processing Record 15 of Set 9 | airai
# Processing Record 16 of Set 9 | znamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 9 | mar del plata
# Processing Record 18 of Set 9 | papara
# Processing Record 19 of Set 9 | yantal
# City not found. Skipping...
# Processing Record 20 of Set 9 | piacabucu
# Processing Record 21 of Set 9 | zarechnyy
# Processing Record 22 of Set 9 | kiama
# Processing Record 23 of Set 9 | kloulklubed
# Processing Record 24 of Set 9 | ashland
# Processing Record 25 of Set 9 | kidal
# Processing Record 26 of Set 9 | hajdusamson
# City not found. Skipping...
# Processing Record 27 of Set 9 | omboue
# Processing Record 28 of Set 9 | loa janan
# Processing Record 29 of Set 9 | fukue
# Processing Record 30 of Set 9 | baykit
# Processing Record 31 of Set 9 | galesong
# Processing Record 32 of Set 9 | samarkand
# Processing Record 33 of Set 9 | daoukro
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | burriana
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | hailar
# Processing Record 38 of Set 9 | rudnogorsk
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | mwinilunga
# Processing Record 41 of Set 9 | sumbe
# Processing Record 42 of Set 9 | nishihara
# Processing Record 43 of Set 9 | bathsheba
# Processing Record 44 of Set 9 | chichimila
# Processing Record 45 of Set 9 | betafo
# Processing Record 46 of Set 9 | karatau
# City not found. Skipping...
# Processing Record 47 of Set 9 | jasper
# Processing Record 48 of Set 9 | weston
# Processing Record 49 of Set 9 | laguna
# Processing Record 1 of Set 10 | bayji
# City not found. Skipping...
# Processing Record 2 of Set 10 | jinka
# Processing Record 3 of Set 10 | lazaro cardenas
# Processing Record 4 of Set 10 | nanaimo
# Processing Record 5 of Set 10 | agnibilekrou
# Processing Record 6 of Set 10 | parana
# Processing Record 7 of Set 10 | bainbridge
# Processing Record 8 of Set 10 | pemba
# Processing Record 9 of Set 10 | north bend
# Processing Record 10 of Set 10 | bud
# Processing Record 11 of Set 10 | bitung
# Processing Record 12 of Set 10 | vamvakofiton
# Processing Record 13 of Set 10 | hofn
# Processing Record 14 of Set 10 | vestmannaeyjar
# Processing Record 15 of Set 10 | sao joao da barra
# Processing Record 16 of Set 10 | alofi
# Processing Record 17 of Set 10 | kautokeino
# Processing Record 18 of Set 10 | mount gambier
# Processing Record 19 of Set 10 | zhigansk
# Processing Record 20 of Set 10 | vila velha
# Processing Record 21 of Set 10 | castelbuono
# Processing Record 22 of Set 10 | matagami
# Processing Record 23 of Set 10 | lengshuitan
# Processing Record 24 of Set 10 | houma
# Processing Record 25 of Set 10 | alcains
# Processing Record 26 of Set 10 | udachnyy
# Processing Record 27 of Set 10 | tres arroyos
# Processing Record 28 of Set 10 | tadine
# Processing Record 29 of Set 10 | turgenevo
# Processing Record 30 of Set 10 | mbanza-ngungu
# Processing Record 31 of Set 10 | rosetta
# City not found. Skipping...
# Processing Record 32 of Set 10 | bay roberts
# City not found. Skipping...
# Processing Record 33 of Set 10 | susanville
# Processing Record 34 of Set 10 | port moresby
# Processing Record 35 of Set 10 | bridgetown
# Processing Record 36 of Set 10 | port augusta
# Processing Record 37 of Set 10 | berlevag
# Processing Record 38 of Set 10 | paamiut
# Processing Record 39 of Set 10 | egvekinot
# City not found. Skipping...
# Processing Record 40 of Set 10 | butembo
# Processing Record 41 of Set 10 | bose
# Processing Record 42 of Set 10 | nyurba
# Processing Record 43 of Set 10 | dhidhdhoo
# Processing Record 44 of Set 10 | novikovo
# Processing Record 45 of Set 10 | alpena
# City not found. Skipping...
# Processing Record 46 of Set 10 | mehran
# Processing Record 47 of Set 10 | koslan
# Processing Record 48 of Set 10 | sweetwater
# Processing Record 49 of Set 10 | dudinka
# Processing Record 1 of Set 11 | mikhaylovskoye
# Processing Record 2 of Set 11 | conakry
# Processing Record 3 of Set 11 | waingapu
# City not found. Skipping...
# Processing Record 4 of Set 11 | hisor
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 11 | tahta
# City not found. Skipping...
# Processing Record 6 of Set 11 | san lorenzo
# Processing Record 7 of Set 11 | kargat
# Processing Record 8 of Set 11 | matamoros
# Processing Record 9 of Set 11 | medvedka
# City not found. Skipping...
# Processing Record 10 of Set 11 | taizhou
# Processing Record 11 of Set 11 | tateyama
# Processing Record 12 of Set 11 | portobelo
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | santa pola
# Processing Record 15 of Set 11 | mecca
# Processing Record 16 of Set 11 | bubaque
# Processing Record 17 of Set 11 | uvarovka
# Processing Record 18 of Set 11 | ornskoldsvik
# Processing Record 19 of Set 11 | houston
# Processing Record 20 of Set 11 | matara
# Processing Record 21 of Set 11 | ferrol
# Processing Record 22 of Set 11 | arona
# Processing Record 23 of Set 11 | dakar
# Processing Record 24 of Set 11 | sehithwa
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | zhaotong
# Processing Record 27 of Set 11 | vieques
# Processing Record 28 of Set 11 | muravlenko
# Processing Record 29 of Set 11 | puerto madryn
# Processing Record 30 of Set 11 | shingu
# Processing Record 31 of Set 11 | tomatlan
# City not found. Skipping...
# Processing Record 32 of Set 11 | tocopilla
# Processing Record 33 of Set 11 | tifton
# Processing Record 34 of Set 11 | sungaipenuh
# Processing Record 35 of Set 11 | mayo
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | alyangula
# Processing Record 38 of Set 11 | bantry
# Processing Record 39 of Set 11 | sabha
# Processing Record 40 of Set 11 | port-cartier
# City not found. Skipping...
# Processing Record 41 of Set 11 | yafran
# Processing Record 42 of Set 11 | kenai
# Processing Record 43 of Set 11 | rodrigues alves
# Processing Record 44 of Set 11 | vardo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 11 | kaeo
# Processing Record 46 of Set 11 | shunyi
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | dasoguz
# Processing Record 49 of Set 11 | teluk nibung
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | dhrangadhra
# Processing Record 3 of Set 12 | maldonado
# Processing Record 4 of Set 12 | creel
# Processing Record 5 of Set 12 | hue
# Processing Record 6 of Set 12 | parabel
# Processing Record 7 of Set 12 | wattegama
# Processing Record 8 of Set 12 | san quintin
# Processing Record 9 of Set 12 | marquard
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | roma
# Processing Record 12 of Set 12 | shelburne
# Processing Record 13 of Set 12 | rawson
# Processing Record 14 of Set 12 | azangaro
# Processing Record 15 of Set 12 | yarkovo
# City not found. Skipping...
# Processing Record 16 of Set 12 | amahai
# Processing Record 17 of Set 12 | verkhnetulomskiy
# Processing Record 18 of Set 12 | rognan
# Processing Record 19 of Set 12 | deogarh
# Processing Record 20 of Set 12 | sao raimundo nonato
# Processing Record 21 of Set 12 | chitral
# Processing Record 22 of Set 12 | tyup
# Processing Record 23 of Set 12 | champerico
# Processing Record 24 of Set 12 | svetlyy
# City not found. Skipping...
# Processing Record 25 of Set 12 | muriwai beach
# Processing Record 26 of Set 12 | ulaanbaatar
# Processing Record 27 of Set 12 | norman wells
# Processing Record 28 of Set 12 | ouadda
# Processing Record 29 of Set 12 | chaykovskaya
# ------------------------------
# Your Data Has Been Retrieved
# ------------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City": city_two,
    "Cloudiness": cloudiness,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}

# Create a DataFrame from the dictionary
weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.head(10)
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0     killybegs         100      IE  1636926635        94  54.6333   -8.4500
# 1        tarsus          65      TR  1636926636        30  36.9188   34.8784
# 2        japura         100      ID  1636926636        92  -0.3167  102.3500
# 3     mahebourg          87      MU  1636926277        76 -20.4081   57.7000
# 4       ahipara          10      NZ  1636926636        78 -35.1667  173.1667
# 5  komsomolskiy          40      UZ  1636926637        71  40.4272   71.7189
# 6   waldkirchen          27      DE  1636926637        92  48.7327   13.6008
# 7         kapaa          90      US  1636926190        69  22.0752 -159.3190
# 8       rikitea         100      PF  1636926162        73 -23.1203 -134.9692
# 9         lagoa         100      PT  1636926297        75  39.0500  -27.9833
#
#    Max Temp  Wind Speed
# 0     51.46        8.86
# 1     60.67        6.15
# 2     73.92        1.12
# 3     76.24       10.45
# 4     67.03       13.13
# 5     47.12        4.61
# 6     40.84        4.00
# 7     81.48        1.01
# 8     74.01       14.34
# 9     65.12       19.26

# %%
# Note to avoid any issues later, use encoding="utf-8"
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %%
weather_df.count()
# Out:
# City          568
# Cloudiness    568
# Country       568
# Date          568
# Humidity      568
# Lat           568
# Lng           568
# Max Temp      568
# Wind Speed    568
# dtype: int64

# %% [markdown]
# # Plotting the Data
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig4.png")
plt.show()
