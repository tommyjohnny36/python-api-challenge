# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# File to Load (Remember to Change These)
file_to_load = r"C:\Users\z0042xeh\Desktop\Georgia Tech\02-Homework\06-Python-APIs\Instructions\python-api-challenge\weather_data.csv"

# Read Purchasing File and store into Pandas data frame
weather_data = pd.read_csv(file_to_load, dtype='object', encoding='utf-8')

weather_data.head(10)
# Out:
#            City Cloudiness Country        Date Humidity       Lat        Lng  \
# 0     killybegs        100      IE  1636926635       94   54.6333      -8.45
# 1        tarsus         65      TR  1636926636       30   36.9188    34.8784
# 2        japura        100      ID  1636926636       92   -0.3167     102.35
# 3     mahebourg         87      MU  1636926277       76  -20.4081       57.7
# 4       ahipara         10      NZ  1636926636       78  -35.1667   173.1667
# 5  komsomolskiy         40      UZ  1636926637       71   40.4272    71.7189
# 6   waldkirchen         27      DE  1636926637       92   48.7327    13.6008
# 7         kapaa         90      US  1636926190       69   22.0752   -159.319
# 8       rikitea        100      PF  1636926162       73  -23.1203  -134.9692
# 9         lagoa        100      PT  1636926297       75     39.05   -27.9833
#
#   Max Temp Wind Speed
# 0    51.46       8.86
# 1    60.67       6.15
# 2    73.92       1.12
# 3    76.24      10.45
# 4    67.03      13.13
# 5    47.12       4.61
# 6    40.84        4.0
# 7    81.48       1.01
# 8    74.01      14.34
# 9    65.12      19.26

# %%
# Drop rows missing data
weather_data_no_null = weather_data.dropna()
weather_data_no_null.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
weather_data_no_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567 entries, 0 to 567
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        567 non-null    object
#  1   Cloudiness  567 non-null    object
#  2   Country     567 non-null    object
#  3   Date        567 non-null    object
#  4   Humidity    567 non-null    object
#  5   Lat         567 non-null    object
#  6   Lng         567 non-null    object
#  7   Max Temp    567 non-null    object
#  8   Wind Speed  567 non-null    object
# dtypes: object(9)
# memory usage: 44.3+ KB

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = weather_data_no_null[["Lat", "Lng"]].astype(float)

# Convert Humidity to float and store
humidity = weather_data_no_null["Humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the DataFrame to find your ideal weather condition. For example:
# Convert Max Temp and store
# max_temp = weather_data_no_null["Max Temp"].astype(float)
# wind_speed = weather_data_no_null['Wind Speed'].astype(float)
# cloudiness = weather_data_no_null['Cloudiness'].astype(float)

# converted_weather_df = pd.DataFrame

# Using astype() to convert a column's data into floats
weather_data_no_null.loc[:, "Max Temp"] = weather_data_no_null["Max Temp"].astype("float")
weather_data_no_null.loc[:, "Wind Speed"] = weather_data_no_null["Wind Speed"].astype("float")
weather_data_no_null.loc[:, "Cloudiness"] = weather_data_no_null["Cloudiness"].astype("float")
weather_data_no_null.loc[:, "Humidity"] = weather_data_no_null["Humidity"].astype("float")

# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 10 mph.
# Zero cloudiness.
ideal_city_df = weather_data_no_null.loc[(weather_data_no_null["Wind Speed"] <= 10) & (weather_data_no_null["Max Temp"] >= 70) & (weather_data_no_null["Max Temp"] <= 80)
                                            & (weather_data_no_null["Cloudiness"] == 0)]

ideal_city_df


# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
# Out:
# C:\Users\z0042xeh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1843: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\Users\z0042xeh\Anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#              City  Cloudiness Country        Date  Humidity       Lat  \
# 44        cordoba         0.0      AR  1636926601      27.0  -31.4135
# 78        salalah         0.0      OM  1636926296      64.0   17.0151
# 123    hambantota         0.0      LK  1636926213     100.0    6.1241
# 149         nizwa         0.0      OM  1636926192      42.0   22.9333
# 301  saint-pierre         0.0      RE  1636926702      73.0  -21.3393
# 331       rafaela         0.0      AR  1636926711      29.0  -31.2503
# 355         aswan         0.0      EG  1636926717      53.0   24.0934
# 446        parana         0.0      AR  1636926506      45.0   -31.732
# 504         mecca         0.0      SA  1636926702      73.0   21.4267
#
#           Lng  Max Temp  Wind Speed
# 44   -64.1811     79.65        9.22
# 78    54.0924     75.29        3.44
# 123   81.1185     75.54        4.61
# 149   57.5333     70.59        2.53
# 301   55.4781     74.84        6.91
# 331  -61.4867     76.98        3.00
# 355    32.907     74.50        8.05
# 446  -60.5238     77.56        6.71
# 504   39.8261     77.67        1.86

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Create a hotel_df
hotel_df = ideal_city_df.loc[:,["City","Country", "Lat", "Lng"]]

# Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""

# Display the result
hotel_df
# Out:
#              City Country       Lat       Lng Hotel Name
# 44        cordoba      AR  -31.4135  -64.1811
# 78        salalah      OM   17.0151   54.0924
# 123    hambantota      LK    6.1241   81.1185
# 149         nizwa      OM   22.9333   57.5333
# 301  saint-pierre      RE  -21.3393   55.4781
# 331       rafaela      AR  -31.2503  -61.4867
# 355         aswan      EG   24.0934    32.907
# 446        parana      AR   -31.732  -60.5238
# 504         mecca      SA   21.4267   39.8261

# %%
# set up a parameters dictionary
params = {
    "keyword": 'hotel',
    "radius": 5000,
    "type": 'hotel',
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
for index, row in hotel_df.iterrows():
    
    # get city name, lat, lng from df
    city_name = row['City']
    lat = row['Lat']
    lng = row['Lng']
    
    # add latitude and longitude to params dict as 'location'
    params['location'] = f'{lat},{lng}'
    
    # assemble url and make API request
    print(f'Currently retrieving results for {index}: {city_name}.')
    
     # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
    
    
    results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # if there is no hotel available, show missing field
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

# Print end of search once searching is completed
print("-------End of Search-------")
# Out:
# Currently retrieving results for 44: cordoba.
# Closest hotel in cordoba is Azur Real Hotel Boutique.
# ------------
# Currently retrieving results for 78: salalah.
# Closest hotel in salalah is Muscat International Hotel plaza Salalah.
# ------------
# Currently retrieving results for 123: hambantota.
# Closest hotel in hambantota is The Peacock Beach Hotel Hambantota.
# ------------
# Currently retrieving results for 149: nizwa.
# Closest hotel in nizwa is Nizwa Hotel Apartments.
# ------------
# Currently retrieving results for 301: saint-pierre.
# Closest hotel in saint-pierre is Le Battant Des Lames.
# ------------
# Currently retrieving results for 331: rafaela.
# Closest hotel in rafaela is Hotel Plaza Rafaela.
# ------------
# Currently retrieving results for 355: aswan.
# Closest hotel in aswan is Sofitel Legend Old Cataract Aswan.
# ------------
# Currently retrieving results for 446: parana.
# Closest hotel in parana is Howard Johnson by Wyndham Plaza Hotel Mayorazgo.
# ------------
# Currently retrieving results for 504: mecca.
# Closest hotel in mecca is Makkah Clock Royal Tower, A Fairmont Hotel.
# ------------
# -------End of Search-------

# %%
hotel_df
# Out:
#              City Country       Lat       Lng  \
# 44        cordoba      AR  -31.4135  -64.1811
# 78        salalah      OM   17.0151   54.0924
# 123    hambantota      LK    6.1241   81.1185
# 149         nizwa      OM   22.9333   57.5333
# 301  saint-pierre      RE  -21.3393   55.4781
# 331       rafaela      AR  -31.2503  -61.4867
# 355         aswan      EG   24.0934    32.907
# 446        parana      AR   -31.732  -60.5238
# 504         mecca      SA   21.4267   39.8261
#
#                                           Hotel Name
# 44                          Azur Real Hotel Boutique
# 78          Muscat International Hotel plaza Salalah
# 123               The Peacock Beach Hotel Hambantota
# 149                           Nizwa Hotel Apartments
# 301                             Le Battant Des Lames
# 331                              Hotel Plaza Rafaela
# 355                Sofitel Legend Old Cataract Aswan
# 446  Howard Johnson by Wyndham Plaza Hotel Mayorazgo
# 504       Makkah Clock Royal Tower, A Fairmont Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer and info box content ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4cbad6f57b71> in <module>
#       1 # Add marker layer and info box content ontop of heat map
# ----> 2 markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       3
#       4 # Add the layer to the map
#       5 fig.add_layer(markers)
#
# ~\Anaconda3\lib\site-packages\gmaps\marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#    1080                 else:
#    1081                     # passthrough args that don't set traits to super
# -> 1082                     super_kwargs[key] = value
#    1083         try:
#    1084             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1214                 for changes in cache.values():
#    1215                     for change in changes:
# -> 1216                         self.notify_change(change)
#    1217
#    1218     def _notify_trait(self, name, old_value, new_value):
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1227     def notify_change(self, change):
#    1228         """Notify observers of a change event"""
# -> 1229         return self._notify_observers(change)
#    1230
#    1231     def _notify_observers(self, event):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in _notify_observers(self, event)
#    1264                 c = getattr(self, c.name)
#    1265
# -> 1266             c(event)
#    1267
#    1268     def _add_notifiers(self, handler, name, type):
#
# ~\Anaconda3\lib\site-packages\gmaps\marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~\Anaconda3\lib\site-packages\gmaps\bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
