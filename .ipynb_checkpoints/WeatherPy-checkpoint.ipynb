# %% [markdown]
# # Analysis
# Temperature seems to have a clear correlation with latitude
# As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). The southern hemisphere tends to be warmer this time of year than the northern hemisphere
# There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities near 0, 80, and 90% cloudiness
# There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind
# Wind speed tends to generally be betweeen 0 and 15 mph regardless of latitude
# There is no strong relationship between latitude and humidity. however there is a slightly larger cluster of northern hemisphere cities with high humidity (above 60% humidity)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import weather_api_key, g_key
temp_units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# Save as a csv


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# # Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | mgandu
# Processing Record 3 of Set 1 | hofn
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | narsaq
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | axim
# Processing Record 19 of Set 1 | genhe
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | arnia
# Processing Record 22 of Set 1 | baruun-urt
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | eyl
# Processing Record 25 of Set 1 | usinsk
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | puerto colombia
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | seddon
# Processing Record 32 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 33 of Set 1 | lazaro cardenas
# City not found. Skipping...
# Processing Record 34 of Set 1 | kasongo-lunda
# Processing Record 35 of Set 1 | hobyo
# Processing Record 36 of Set 1 | puerto ayacucho
# Processing Record 37 of Set 1 | kulhudhuffushi
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | griffith
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | haines junction
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | san cristobal
# Processing Record 44 of Set 1 | upata
# Processing Record 45 of Set 1 | goderich
# Processing Record 46 of Set 1 | harper
# Processing Record 47 of Set 1 | yumen
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | castro
# Processing Record 1 of Set 2 | astoria
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 4 of Set 2 | kolpashevo
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | vieste
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | ahipara
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | baracoa
# Processing Record 13 of Set 2 | lompoc
# Processing Record 14 of Set 2 | paraiso
# Processing Record 15 of Set 2 | bud
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | callaway
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | vanimo
# City not found. Skipping...
# Processing Record 21 of Set 2 | manali
# Processing Record 22 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | yatou
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | vao
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | jilib
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | asosa
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | tatarskaya kargala
# Processing Record 33 of Set 2 | yanam
# City not found. Skipping...
# Processing Record 34 of Set 2 | paso de los toros
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | derac
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | asyut
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | alofi
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | valley
# Processing Record 44 of Set 2 | martapura
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | sibolga
# Processing Record 47 of Set 2 | okato
# Processing Record 48 of Set 2 | zaysan
# Processing Record 49 of Set 2 | palana
# Processing Record 1 of Set 3 | maniitsoq
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | esil
# Processing Record 4 of Set 3 | tahlequah
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | healdsburg
# Processing Record 7 of Set 3 | neiafu
# Processing Record 8 of Set 3 | matara
# Processing Record 9 of Set 3 | urubicha
# Processing Record 10 of Set 3 | chicaman
# Processing Record 11 of Set 3 | porto novo
# Processing Record 12 of Set 3 | krasnoturansk
# Processing Record 13 of Set 3 | naze
# City not found. Skipping...
# Processing Record 14 of Set 3 | mys shmidta
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | meulaboh
# Processing Record 17 of Set 3 | grand forks
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | lund
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | almeirim
# Processing Record 25 of Set 3 | camocim
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | pangnirtung
# Processing Record 28 of Set 3 | terrace bay
# Processing Record 29 of Set 3 | batagay-alyta
# City not found. Skipping...
# Processing Record 30 of Set 3 | yerbogachen
# Processing Record 31 of Set 3 | leshukonskoye
# Processing Record 32 of Set 3 | ambulu
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | bozeman
# Processing Record 35 of Set 3 | victor harbor
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | port blair
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | yellowknife
# City not found. Skipping...
# Processing Record 40 of Set 3 | avera
# Processing Record 41 of Set 3 | abu samrah
# Processing Record 42 of Set 3 | alice springs
# Processing Record 43 of Set 3 | cibitoke
# Processing Record 44 of Set 3 | airai
# City not found. Skipping...
# Processing Record 45 of Set 3 | coari
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | pavlodar
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | bandarbeyla
# Processing Record 1 of Set 4 | loukhi
# Processing Record 2 of Set 4 | faya
# Processing Record 3 of Set 4 | parvatsar
# Processing Record 4 of Set 4 | san matias
# Processing Record 5 of Set 4 | ramhormoz
# Processing Record 6 of Set 4 | corpus christi
# City not found. Skipping...
# Processing Record 7 of Set 4 | necochea
# Processing Record 8 of Set 4 | saint-georges
# Processing Record 9 of Set 4 | nyurba
# Processing Record 10 of Set 4 | saint-joseph
# Processing Record 11 of Set 4 | mitsamiouli
# Processing Record 12 of Set 4 | gigmoto
# City not found. Skipping...
# Processing Record 13 of Set 4 | ardakan
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | marsh harbour
# Processing Record 19 of Set 4 | honiara
# Processing Record 20 of Set 4 | lianyuan
# Processing Record 21 of Set 4 | san juan
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | hovd
# City not found. Skipping...
# Processing Record 24 of Set 4 | chara
# Processing Record 25 of Set 4 | gardendale
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | marzuq
# Processing Record 31 of Set 4 | iquitos
# Processing Record 32 of Set 4 | kargasok
# Processing Record 33 of Set 4 | beloha
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | megalopoli
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | yulara
# Processing Record 40 of Set 4 | kizema
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | santa cruz de la palma
# Processing Record 43 of Set 4 | derzhavinsk
# Processing Record 44 of Set 4 | jiblah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 4 | tungor
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | sal rei
# Processing Record 48 of Set 4 | richards bay
# Processing Record 49 of Set 4 | alenquer
# Processing Record 1 of Set 5 | tazovskiy
# Processing Record 2 of Set 5 | yar-sale
# Processing Record 3 of Set 5 | lima
# Processing Record 4 of Set 5 | ilulissat
# Processing Record 5 of Set 5 | teya
# Processing Record 6 of Set 5 | boa vista
# Processing Record 7 of Set 5 | bria
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | cayenne
# Processing Record 10 of Set 5 | algeciras
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | stromness
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | huilong
# Processing Record 15 of Set 5 | ivanteyevka
# Processing Record 16 of Set 5 | paranaiba
# Processing Record 17 of Set 5 | ust-maya
# Processing Record 18 of Set 5 | cabano
# Processing Record 19 of Set 5 | fort nelson
# Processing Record 20 of Set 5 | belyy yar
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | adre
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | darhan
# Processing Record 27 of Set 5 | iranshahr
# Processing Record 28 of Set 5 | panguipulli
# Processing Record 29 of Set 5 | perth
# Processing Record 30 of Set 5 | ayr
# Processing Record 31 of Set 5 | saint-pierre
# Processing Record 32 of Set 5 | coahuayana
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | killarney
# Processing Record 35 of Set 5 | springbok
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | waipawa
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | emet
# City not found. Skipping...
# Processing Record 40 of Set 5 | bilibino
# City not found. Skipping...
# Processing Record 41 of Set 5 | oriximina
# Processing Record 42 of Set 5 | zonguldak
# Processing Record 43 of Set 5 | bozoum
# Processing Record 44 of Set 5 | kuytun
# Processing Record 45 of Set 5 | yarmouth
# Processing Record 46 of Set 5 | mogadishu
# Processing Record 47 of Set 5 | charters towers
# Processing Record 48 of Set 5 | santa ines
# Processing Record 49 of Set 5 | baudh
# Processing Record 1 of Set 6 | salalah
# Processing Record 2 of Set 6 | savalou
# Processing Record 3 of Set 6 | katherine
# Processing Record 4 of Set 6 | kutum
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 6 | grand river south east
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | amos
# Processing Record 8 of Set 6 | norton shores
# Processing Record 9 of Set 6 | kogon
# Processing Record 10 of Set 6 | sao bartolomeu de messines
# Processing Record 11 of Set 6 | langsa
# Processing Record 12 of Set 6 | mackay
# Processing Record 13 of Set 6 | esfarayen
# City not found. Skipping...
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | beringovskiy
# Processing Record 16 of Set 6 | kapuskasing
# Processing Record 17 of Set 6 | lichinga
# City not found. Skipping...
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | campbell river
# Processing Record 20 of Set 6 | zyryanskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | alta floresta
# Processing Record 22 of Set 6 | suntar
# Processing Record 23 of Set 6 | sola
# Processing Record 24 of Set 6 | bambanglipuro
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | hazorasp
# Processing Record 27 of Set 6 | wasilla
# Processing Record 28 of Set 6 | shimoda
# Processing Record 29 of Set 6 | coquimbo
# Processing Record 30 of Set 6 | mecca
# City not found. Skipping...
# Processing Record 31 of Set 6 | kargopol
# Processing Record 32 of Set 6 | lata
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | kurilsk
# Processing Record 35 of Set 6 | smirnykh
# Processing Record 36 of Set 6 | khilok
# Processing Record 37 of Set 6 | chippewa falls
# Processing Record 38 of Set 6 | ramona
# Processing Record 39 of Set 6 | merauke
# Processing Record 40 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 6 | shieli
# Processing Record 42 of Set 6 | vestmanna
# Processing Record 43 of Set 6 | sarkand
# Processing Record 44 of Set 6 | agadez
# Processing Record 45 of Set 6 | liku
# Processing Record 46 of Set 6 | yinchuan
# Processing Record 47 of Set 6 | nalut
# Processing Record 48 of Set 6 | yangjiang
# City not found. Skipping...
# Processing Record 49 of Set 6 | geraldton
# Processing Record 1 of Set 7 | tuni
# Processing Record 2 of Set 7 | iqaluit
# Processing Record 3 of Set 7 | saint-francois
# Processing Record 4 of Set 7 | mandurah
# Processing Record 5 of Set 7 | east london
# Processing Record 6 of Set 7 | wanning
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | denham springs
# Processing Record 10 of Set 7 | ouango
# Processing Record 11 of Set 7 | rundu
# City not found. Skipping...
# Processing Record 12 of Set 7 | goure
# Processing Record 13 of Set 7 | khorixas
# Processing Record 14 of Set 7 | new amsterdam
# Processing Record 15 of Set 7 | grand gaube
# Processing Record 16 of Set 7 | eltham
# Processing Record 17 of Set 7 | tasiilaq
# Processing Record 18 of Set 7 | guayaramerin
# Processing Record 19 of Set 7 | asilah
# Processing Record 20 of Set 7 | avesta
# Processing Record 21 of Set 7 | dufftown
# Processing Record 22 of Set 7 | talkha
# City not found. Skipping...
# Processing Record 23 of Set 7 | santa rosalia
# Processing Record 24 of Set 7 | mizdah
# Processing Record 25 of Set 7 | agar
# Processing Record 26 of Set 7 | victoria
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | troitskoye
# Processing Record 29 of Set 7 | inuvik
# Processing Record 30 of Set 7 | ericeira
# City not found. Skipping...
# Processing Record 31 of Set 7 | vredendal
# Processing Record 32 of Set 7 | sitka
# Processing Record 33 of Set 7 | soanierana ivongo
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | aswan
# City not found. Skipping...
# Processing Record 36 of Set 7 | deniliquin
# Processing Record 37 of Set 7 | havre-saint-pierre
# Processing Record 38 of Set 7 | nanortalik
# City not found. Skipping...
# Processing Record 39 of Set 7 | oksovskiy
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | aksu
# Processing Record 42 of Set 7 | maragogi
# Processing Record 43 of Set 7 | matata
# Processing Record 44 of Set 7 | mombetsu
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | malkangiri
# City not found. Skipping...
# Processing Record 47 of Set 7 | salinas
# Processing Record 48 of Set 7 | portland
# Processing Record 49 of Set 7 | riberalta
# Processing Record 1 of Set 8 | tulnici
# City not found. Skipping...
# Processing Record 2 of Set 8 | viedma
# Processing Record 3 of Set 8 | sobolevo
# Processing Record 4 of Set 8 | antalya
# City not found. Skipping...
# Processing Record 5 of Set 8 | bobcaygeon
# Processing Record 6 of Set 8 | amazar
# Processing Record 7 of Set 8 | washougal
# Processing Record 8 of Set 8 | cortes
# Processing Record 9 of Set 8 | ilmajoki
# City not found. Skipping...
# Processing Record 10 of Set 8 | cermik
# Processing Record 11 of Set 8 | aasiaat
# Processing Record 12 of Set 8 | port said
# Processing Record 13 of Set 8 | chuy
# Processing Record 14 of Set 8 | praia da vitoria
# Processing Record 15 of Set 8 | takoradi
# Processing Record 16 of Set 8 | aklavik
# Processing Record 17 of Set 8 | tankara
# Processing Record 18 of Set 8 | farafangana
# Processing Record 19 of Set 8 | gat
# Processing Record 20 of Set 8 | muisne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 8 | araouane
# Processing Record 22 of Set 8 | demyansk
# City not found. Skipping...
# Processing Record 23 of Set 8 | egvekinot
# Processing Record 24 of Set 8 | halifax
# Processing Record 25 of Set 8 | komsomolskiy
# Processing Record 26 of Set 8 | qasigiannguit
# Processing Record 27 of Set 8 | gobabis
# Processing Record 28 of Set 8 | moyale
# Processing Record 29 of Set 8 | zyryanka
# Processing Record 30 of Set 8 | pithapuram
# Processing Record 31 of Set 8 | dwarka
# Processing Record 32 of Set 8 | vaasa
# Processing Record 33 of Set 8 | zhigansk
# Processing Record 34 of Set 8 | araguacu
# Processing Record 35 of Set 8 | ust-nera
# Processing Record 36 of Set 8 | asbestovskiy
# Processing Record 37 of Set 8 | altamira
# Processing Record 38 of Set 8 | buritama
# Processing Record 39 of Set 8 | dali
# Processing Record 40 of Set 8 | surt
# Processing Record 41 of Set 8 | bonavista
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | casma
# Processing Record 44 of Set 8 | tena
# Processing Record 45 of Set 8 | ngorongoro
# Processing Record 46 of Set 8 | namtsy
# City not found. Skipping...
# Processing Record 47 of Set 8 | lavumisa
# Processing Record 48 of Set 8 | ardalstangen
# Processing Record 49 of Set 8 | nichinan
# Processing Record 1 of Set 9 | formosa
# Processing Record 2 of Set 9 | broome
# City not found. Skipping...
# Processing Record 3 of Set 9 | scottsbluff
# Processing Record 4 of Set 9 | kavieng
# City not found. Skipping...
# Processing Record 5 of Set 9 | jimenez
# Processing Record 6 of Set 9 | krutikha
# Processing Record 7 of Set 9 | beoumi
# Processing Record 8 of Set 9 | celestun
# Processing Record 9 of Set 9 | campbellsville
# Processing Record 10 of Set 9 | bosaso
# City not found. Skipping...
# Processing Record 11 of Set 9 | bathsheba
# Processing Record 12 of Set 9 | provost
# Processing Record 13 of Set 9 | lanzhou
# Processing Record 14 of Set 9 | socol
# Processing Record 15 of Set 9 | lawrenceburg
# Processing Record 16 of Set 9 | beauvais
# Processing Record 17 of Set 9 | inverell
# Processing Record 18 of Set 9 | cabadiangan
# Processing Record 19 of Set 9 | vanderhoof
# Processing Record 20 of Set 9 | damietta
# Processing Record 21 of Set 9 | bengkulu
# Processing Record 22 of Set 9 | ondjiva
# Processing Record 23 of Set 9 | celarevo
# Processing Record 24 of Set 9 | mananjary
# Processing Record 25 of Set 9 | fonte boa
# Processing Record 26 of Set 9 | oussouye
# Processing Record 27 of Set 9 | vila do maio
# Processing Record 28 of Set 9 | marienburg
# Processing Record 29 of Set 9 | buala
# Processing Record 30 of Set 9 | ponta delgada
# Processing Record 31 of Set 9 | cairns
# Processing Record 32 of Set 9 | chipinge
# Processing Record 33 of Set 9 | amapa
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | kathu
# Processing Record 36 of Set 9 | cotonou
# Processing Record 37 of Set 9 | ntoum
# Processing Record 38 of Set 9 | lohardaga
# Processing Record 39 of Set 9 | marawi
# Processing Record 40 of Set 9 | lincoln
# Processing Record 41 of Set 9 | anloga
# Processing Record 42 of Set 9 | port macquarie
# Processing Record 43 of Set 9 | mao
# Processing Record 44 of Set 9 | poitiers
# Processing Record 45 of Set 9 | camana
# Processing Record 46 of Set 9 | omboue
# City not found. Skipping...
# Processing Record 47 of Set 9 | jacareacanga
# Processing Record 48 of Set 9 | redmond
# Processing Record 49 of Set 9 | mosquera
# Processing Record 1 of Set 10 | isilkul
# Processing Record 2 of Set 10 | leh
# Processing Record 3 of Set 10 | akureyri
# Processing Record 4 of Set 10 | barro
# Processing Record 5 of Set 10 | ibra
# Processing Record 6 of Set 10 | bani walid
# Processing Record 7 of Set 10 | barsovo
# Processing Record 8 of Set 10 | port shepstone
# Processing Record 9 of Set 10 | sawtell
# Processing Record 10 of Set 10 | camacha
# Processing Record 11 of Set 10 | nantucket
# Processing Record 12 of Set 10 | melekhovo
# Processing Record 13 of Set 10 | fare
# Processing Record 14 of Set 10 | bereda
# Processing Record 15 of Set 10 | raudeberg
# Processing Record 16 of Set 10 | tsiroanomandidy
# Processing Record 17 of Set 10 | prainha
# Processing Record 18 of Set 10 | arlit
# Processing Record 19 of Set 10 | brae
# Processing Record 20 of Set 10 | porto velho
# Processing Record 21 of Set 10 | hargeysa
# City not found. Skipping...
# Processing Record 22 of Set 10 | jardim
# Processing Record 23 of Set 10 | mabaruma
# Processing Record 24 of Set 10 | okha
# Processing Record 25 of Set 10 | alihe
# Processing Record 26 of Set 10 | rio grande
# Processing Record 27 of Set 10 | buraydah
# Processing Record 28 of Set 10 | ketchikan
# Processing Record 29 of Set 10 | boulder city
# Processing Record 30 of Set 10 | plettenberg bay
# Processing Record 31 of Set 10 | lokosovo
# Processing Record 32 of Set 10 | richard toll
# Processing Record 33 of Set 10 | shingu
# Processing Record 34 of Set 10 | noyabrsk
# Processing Record 35 of Set 10 | ambilobe
# Processing Record 36 of Set 10 | zaria
# Processing Record 37 of Set 10 | shenjiamen
# City not found. Skipping...
# Processing Record 38 of Set 10 | bam
# Processing Record 39 of Set 10 | hay river
# Processing Record 40 of Set 10 | debre tabor
# Processing Record 41 of Set 10 | srednekolymsk
# Processing Record 42 of Set 10 | kusa
# Processing Record 43 of Set 10 | ayan
# Processing Record 44 of Set 10 | albania
# Processing Record 45 of Set 10 | tonantins
# City not found. Skipping...
# Processing Record 46 of Set 10 | houma
# Processing Record 47 of Set 10 | smithers
# Processing Record 48 of Set 10 | kapoeta
# City not found. Skipping...
# Processing Record 49 of Set 10 | margate
# Processing Record 1 of Set 11 | kuching
# City not found. Skipping...
# Processing Record 2 of Set 11 | hengshan
# Processing Record 3 of Set 11 | praya
# Processing Record 4 of Set 11 | zhuhai
# Processing Record 5 of Set 11 | bairiki
# Processing Record 6 of Set 11 | muriti
# Processing Record 7 of Set 11 | ariquemes
# Processing Record 8 of Set 11 | eregli
# Processing Record 9 of Set 11 | tselinnoye
# Processing Record 10 of Set 11 | ejido
# Processing Record 11 of Set 11 | majene
# Processing Record 12 of Set 11 | baherden
# Processing Record 13 of Set 11 | fairbanks
# City not found. Skipping...
# Processing Record 14 of Set 11 | visnes
# Processing Record 15 of Set 11 | olenegorsk
# Processing Record 16 of Set 11 | bronnoysund
# Processing Record 17 of Set 11 | kiunga
# Processing Record 18 of Set 11 | sheridan
# City not found. Skipping...
# Processing Record 19 of Set 11 | loksa
# Processing Record 20 of Set 11 | grand baie
# Processing Record 21 of Set 11 | tommot
# Processing Record 22 of Set 11 | hualmay
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | oranjemund
# Processing Record 25 of Set 11 | olafsvik
# Processing Record 26 of Set 11 | aguining
# Processing Record 27 of Set 11 | college
# Processing Record 28 of Set 11 | ankang
# Processing Record 29 of Set 11 | korla
# Processing Record 30 of Set 11 | juegang
# City not found. Skipping...
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | stykkisholmur
# Processing Record 33 of Set 11 | kununurra
# Processing Record 34 of Set 11 | ilheus
# Processing Record 35 of Set 11 | rengo
# Processing Record 36 of Set 11 | talara
# Processing Record 37 of Set 11 | petrivka
# Processing Record 38 of Set 11 | huarmey
# Processing Record 39 of Set 11 | morondava
# Processing Record 40 of Set 11 | harboore
# Processing Record 41 of Set 11 | vila velha
# Processing Record 42 of Set 11 | kharan
# Processing Record 43 of Set 11 | port moresby
# Processing Record 44 of Set 11 | havelock
# City not found. Skipping...
# Processing Record 45 of Set 11 | kaeo
# Processing Record 46 of Set 11 | cap malheureux
# Processing Record 47 of Set 11 | blagoyevo
# Processing Record 48 of Set 11 | maningrida
# Processing Record 49 of Set 11 | north bend
# Processing Record 1 of Set 12 | igarka
# Processing Record 2 of Set 12 | villa carlos paz
# Processing Record 3 of Set 12 | dogondoutchi
# Processing Record 4 of Set 12 | valparaiso
# Processing Record 5 of Set 12 | penzance
# Processing Record 6 of Set 12 | numan
# Processing Record 7 of Set 12 | pilar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 12 | puerto pinasco
# Processing Record 9 of Set 12 | sinjar
# Processing Record 10 of Set 12 | kasamwa
# Processing Record 11 of Set 12 | tual
# Processing Record 12 of Set 12 | gizo
# Processing Record 13 of Set 12 | mubi
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City": city_two,
    "Cloudiness": cloudiness,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Latitude": lats,
    "Longitude": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}

# Create a DataFrame from the dictionary
weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.head(10)
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0         bluff         100      NZ  1636845543        88  -46.6000
# 1        mgandu          65      TZ  1636845543        51   -5.9500
# 2          hofn         100      IS  1636845544        97   64.2539
# 3     mahebourg          40      MU  1636845544        83  -20.4081
# 4       mataura         100      NZ  1636845544        99  -46.1927
# 5         vaini          75      TO  1636845545        78  -21.2000
# 6    butaritari          36      KI  1636845545        75    3.0707
# 7  punta arenas          74      PH  1636845546        87    8.9897
# 8  norman wells           1      US  1636845364        36   35.2226
# 9        narsaq           1      GL  1636845546        81   60.9167
#
#    Longitude  Max Temp  Wind Speed
# 0   168.3333     50.40        9.31
# 1    34.1333     68.45        9.51
# 2   -15.2082     48.24       28.61
# 3    57.7000     75.49        9.22
# 4   168.8643     48.97        1.57
# 5  -175.2000     80.76       12.66
# 6   172.7902     82.11       15.30
# 7   125.3400     78.31        3.62
# 8   -97.4395     60.69       10.36
# 9   -46.0500     16.02        3.04

# %%
# Note to avoid any issues later, use encoding="utf-8"
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %%
weather_df.count()
# Out:
# City          552
# Cloudiness    552
# Country       552
# Date          552
# Humidity      552
# Latitude      552
# Longitude     552
# Max Temp      552
# Wind Speed    552
# dtype: int64

# %% [markdown]
# # Plotting the Data
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig4.png")
plt.show()
