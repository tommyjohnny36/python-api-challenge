# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

temp_units = "imperial"

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 576

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
city_two = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nYour Data Has Been Retrieved\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | zhigansk
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | westport
# Processing Record 5 of Set 1 | saint-philippe
# City not found. Skipping...
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | olafsvik
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | ixtapa
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | sinnamary
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | sisimiut
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | garowe
# Processing Record 26 of Set 1 | hobyo
# Processing Record 27 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 28 of Set 1 | yumen
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | lanzhou
# Processing Record 31 of Set 1 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 32 of Set 1 | kungurtug
# Processing Record 33 of Set 1 | hoi an
# Processing Record 34 of Set 1 | pavlovsk
# City not found. Skipping...
# Processing Record 35 of Set 1 | saint-pierre
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | cajazeiras
# City not found. Skipping...
# Processing Record 39 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 40 of Set 1 | buala
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | san pedro
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | grand river south east
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | toamasina
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | acapulco
# Processing Record 3 of Set 2 | ust-kuyga
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | amga
# Processing Record 6 of Set 2 | manbij
# Processing Record 7 of Set 2 | chino valley
# Processing Record 8 of Set 2 | santiago de las vegas
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | palimbang
# Processing Record 12 of Set 2 | lebu
# City not found. Skipping...
# Processing Record 13 of Set 2 | makakilo city
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | taupo
# City not found. Skipping...
# Processing Record 16 of Set 2 | faya
# Processing Record 17 of Set 2 | sokoni
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | basoko
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | aktau
# Processing Record 23 of Set 2 | calabozo
# Processing Record 24 of Set 2 | mastic beach
# City not found. Skipping...
# Processing Record 25 of Set 2 | saint-joseph
# Processing Record 26 of Set 2 | chinhoyi
# Processing Record 27 of Set 2 | esperance
# Processing Record 28 of Set 2 | poum
# Processing Record 29 of Set 2 | kumla
# Processing Record 30 of Set 2 | santa lucia
# Processing Record 31 of Set 2 | panacan
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | kamina
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | areka
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | wairoa
# City not found. Skipping...
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | vostok
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | laguna
# Processing Record 44 of Set 2 | sturgis
# City not found. Skipping...
# Processing Record 45 of Set 2 | caravelas
# Processing Record 46 of Set 2 | ipixuna
# Processing Record 47 of Set 2 | hegra
# Processing Record 48 of Set 2 | kerema
# Processing Record 49 of Set 2 | khatanga
# Processing Record 1 of Set 3 | rikitea
# Processing Record 2 of Set 3 | asau
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | kosh-agach
# City not found. Skipping...
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | santiago
# Processing Record 9 of Set 3 | mount isa
# Processing Record 10 of Set 3 | aloleng
# Processing Record 11 of Set 3 | sapouy
# Processing Record 12 of Set 3 | provideniya
# City not found. Skipping...
# Processing Record 13 of Set 3 | jalu
# City not found. Skipping...
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | kavieng
# Processing Record 16 of Set 3 | mingshui
# City not found. Skipping...
# Processing Record 17 of Set 3 | payo
# Processing Record 18 of Set 3 | port-gentil
# Processing Record 19 of Set 3 | porto de moz
# Processing Record 20 of Set 3 | suntar
# Processing Record 21 of Set 3 | pampierstad
# Processing Record 22 of Set 3 | udachnyy
# Processing Record 23 of Set 3 | rorvik
# Processing Record 24 of Set 3 | wanning
# Processing Record 25 of Set 3 | nemuro
# Processing Record 26 of Set 3 | baykit
# Processing Record 27 of Set 3 | tulun
# Processing Record 28 of Set 3 | gladstone
# Processing Record 29 of Set 3 | heishan
# City not found. Skipping...
# Processing Record 30 of Set 3 | linjiang
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | leningradskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | znamenskoye
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | shestakovo
# Processing Record 36 of Set 3 | iquique
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | kutum
# Processing Record 39 of Set 3 | hokitika
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | axim
# Processing Record 42 of Set 3 | gimli
# Processing Record 43 of Set 3 | naryan-mar
# Processing Record 44 of Set 3 | taoudenni
# Processing Record 45 of Set 3 | lokosovo
# Processing Record 46 of Set 3 | maridi
# Processing Record 47 of Set 3 | isangel
# City not found. Skipping...
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | imeni poliny osipenko
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | richards bay
# Processing Record 3 of Set 4 | fortuna
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | concordia
# Processing Record 6 of Set 4 | cherdyn
# Processing Record 7 of Set 4 | nuevo progreso
# Processing Record 8 of Set 4 | sobolevo
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | astoria
# Processing Record 11 of Set 4 | dongling
# Processing Record 12 of Set 4 | victoria
# Processing Record 13 of Set 4 | daltenganj
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | alamosa
# City not found. Skipping...
# Processing Record 16 of Set 4 | yulara
# Processing Record 17 of Set 4 | rakitnoye
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | nalut
# City not found. Skipping...
# Processing Record 20 of Set 4 | adrar
# Processing Record 21 of Set 4 | iqaluit
# Processing Record 22 of Set 4 | katherine
# Processing Record 23 of Set 4 | darhan
# Processing Record 24 of Set 4 | kamaishi
# City not found. Skipping...
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | igrim
# Processing Record 27 of Set 4 | roma
# Processing Record 28 of Set 4 | dedovichi
# City not found. Skipping...
# Processing Record 29 of Set 4 | beidao
# Processing Record 30 of Set 4 | buin
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | bonthe
# Processing Record 33 of Set 4 | komsomolskiy
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | faanui
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | saint-francois
# City not found. Skipping...
# Processing Record 41 of Set 4 | east london
# Processing Record 42 of Set 4 | khandyga
# Processing Record 43 of Set 4 | sola
# Processing Record 44 of Set 4 | inta
# Processing Record 45 of Set 4 | linxia
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | pasighat
# City not found. Skipping...
# Processing Record 48 of Set 4 | phan rang
# Processing Record 49 of Set 4 | san luis
# Processing Record 1 of Set 5 | beringovskiy
# Processing Record 2 of Set 5 | sao filipe
# Processing Record 3 of Set 5 | atar
# Processing Record 4 of Set 5 | aquiraz
# Processing Record 5 of Set 5 | biltine
# Processing Record 6 of Set 5 | iralaya
# Processing Record 7 of Set 5 | sechura
# Processing Record 8 of Set 5 | stokmarknes
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | carnarvon
# City not found. Skipping...
# Processing Record 12 of Set 5 | srandakan
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | kashi
# Processing Record 15 of Set 5 | salalah
# City not found. Skipping...
# Processing Record 16 of Set 5 | baruun-urt
# Processing Record 17 of Set 5 | norwich
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | apatfalva
# Processing Record 21 of Set 5 | columbia
# Processing Record 22 of Set 5 | oudtshoorn
# Processing Record 23 of Set 5 | katobu
# Processing Record 24 of Set 5 | zhaotong
# Processing Record 25 of Set 5 | divnoye
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | ilawe
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | northam
# Processing Record 30 of Set 5 | malabo
# Processing Record 31 of Set 5 | ambilobe
# Processing Record 32 of Set 5 | pacific grove
# Processing Record 33 of Set 5 | uribia
# Processing Record 34 of Set 5 | najran
# Processing Record 35 of Set 5 | payakumbuh
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 5 | caxito
# Processing Record 39 of Set 5 | iyo
# Processing Record 40 of Set 5 | parnarama
# Processing Record 41 of Set 5 | fairbanks
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 | chapleau
# City not found. Skipping...
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | nosy varika
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | uglovskoye
# Processing Record 47 of Set 5 | pierre
# Processing Record 48 of Set 5 | lufilufi
# Processing Record 49 of Set 5 | kahuta
# Processing Record 1 of Set 6 | kampot
# Processing Record 2 of Set 6 | scarborough
# City not found. Skipping...
# Processing Record 3 of Set 6 | vicosa
# Processing Record 4 of Set 6 | korla
# Processing Record 5 of Set 6 | ichinohe
# Processing Record 6 of Set 6 | linguere
# City not found. Skipping...
# Processing Record 7 of Set 6 | griffith
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | marana
# City not found. Skipping...
# Processing Record 10 of Set 6 | lagoa
# Processing Record 11 of Set 6 | kislyakovskaya
# Processing Record 12 of Set 6 | evensk
# Processing Record 13 of Set 6 | vao
# Processing Record 14 of Set 6 | sidi qasim
# Processing Record 15 of Set 6 | yuli
# Processing Record 16 of Set 6 | airai
# Processing Record 17 of Set 6 | norman wells
# Processing Record 18 of Set 6 | quelimane
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | yaring
# Processing Record 21 of Set 6 | port blair
# Processing Record 22 of Set 6 | sovetskiy
# Processing Record 23 of Set 6 | onufriyivka
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | gamba
# Processing Record 26 of Set 6 | ketchikan
# Processing Record 27 of Set 6 | volnovakha
# Processing Record 28 of Set 6 | vaitape
# Processing Record 29 of Set 6 | lengshuitan
# Processing Record 30 of Set 6 | muros
# Processing Record 31 of Set 6 | kindu
# Processing Record 32 of Set 6 | laksar
# Processing Record 33 of Set 6 | surt
# Processing Record 34 of Set 6 | longyearbyen
# Processing Record 35 of Set 6 | jacksonville
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | kontagora
# Processing Record 38 of Set 6 | palmer
# Processing Record 39 of Set 6 | kysyl-syr
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | nelson bay
# Processing Record 42 of Set 6 | buraydah
# Processing Record 43 of Set 6 | pitea
# Processing Record 44 of Set 6 | ambovombe
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | noumea
# Processing Record 47 of Set 6 | marrakesh
# Processing Record 48 of Set 6 | dongsheng
# City not found. Skipping...
# Processing Record 49 of Set 6 | loukhi
# Processing Record 1 of Set 7 | okha
# Processing Record 2 of Set 7 | lensk
# Processing Record 3 of Set 7 | krasnoselkup
# Processing Record 4 of Set 7 | anacortes
# Processing Record 5 of Set 7 | bongandanga
# City not found. Skipping...
# Processing Record 6 of Set 7 | lahaina
# Processing Record 7 of Set 7 | onalaska
# Processing Record 8 of Set 7 | yarkovo
# Processing Record 9 of Set 7 | cap malheureux
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | tehri
# Processing Record 12 of Set 7 | high level
# Processing Record 13 of Set 7 | pisco
# Processing Record 14 of Set 7 | olinda
# Processing Record 15 of Set 7 | zhuanghe
# Processing Record 16 of Set 7 | sembe
# Processing Record 17 of Set 7 | mazamari
# Processing Record 18 of Set 7 | jasper
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | lata
# Processing Record 21 of Set 7 | tosno
# Processing Record 22 of Set 7 | santa cruz
# Processing Record 23 of Set 7 | ivanteyevka
# Processing Record 24 of Set 7 | makhinjauri
# City not found. Skipping...
# Processing Record 25 of Set 7 | amarillo
# City not found. Skipping...
# Processing Record 26 of Set 7 | arinos
# Processing Record 27 of Set 7 | honningsvag
# City not found. Skipping...
# Processing Record 28 of Set 7 | minsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | boden
# Processing Record 30 of Set 7 | gangapur
# Processing Record 31 of Set 7 | danilov
# Processing Record 32 of Set 7 | harindanga
# Processing Record 33 of Set 7 | bouca
# Processing Record 34 of Set 7 | jaisalmer
# Processing Record 35 of Set 7 | martapura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 7 | armizonskoye
# Processing Record 37 of Set 7 | eureka
# Processing Record 38 of Set 7 | krasnokholmskiy
# Processing Record 39 of Set 7 | lagos
# Processing Record 40 of Set 7 | bhuj
# Processing Record 41 of Set 7 | cabo san lucas
# Processing Record 42 of Set 7 | mwinilunga
# Processing Record 43 of Set 7 | leshukonskoye
# City not found. Skipping...
# Processing Record 44 of Set 7 | lorengau
# Processing Record 45 of Set 7 | padang
# Processing Record 46 of Set 7 | priboj
# City not found. Skipping...
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | mandalgovi
# Processing Record 49 of Set 7 | porto novo
# Processing Record 1 of Set 8 | hals
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | sao raimundo das mangabeiras
# City not found. Skipping...
# Processing Record 4 of Set 8 | fort saint john
# Processing Record 5 of Set 8 | dzaoudzi
# Processing Record 6 of Set 8 | kawalu
# Processing Record 7 of Set 8 | hojai
# Processing Record 8 of Set 8 | vokhma
# Processing Record 9 of Set 8 | imbituba
# Processing Record 10 of Set 8 | maraba
# Processing Record 11 of Set 8 | hamilton
# Processing Record 12 of Set 8 | port lincoln
# Processing Record 13 of Set 8 | sioux lookout
# Processing Record 14 of Set 8 | presidente olegario
# Processing Record 15 of Set 8 | tigil
# Processing Record 16 of Set 8 | tefe
# Processing Record 17 of Set 8 | sao felix do xingu
# Processing Record 18 of Set 8 | kalianget
# City not found. Skipping...
# Processing Record 19 of Set 8 | banda aceh
# Processing Record 20 of Set 8 | lae
# Processing Record 21 of Set 8 | villacarrillo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 8 | xai-xai
# Processing Record 23 of Set 8 | bengkulu
# Processing Record 24 of Set 8 | ilulissat
# Processing Record 25 of Set 8 | lerwick
# Processing Record 26 of Set 8 | eirunepe
# Processing Record 27 of Set 8 | nishihara
# Processing Record 28 of Set 8 | berdigestyakh
# Processing Record 29 of Set 8 | bilma
# Processing Record 30 of Set 8 | mackay
# Processing Record 31 of Set 8 | koson
# Processing Record 32 of Set 8 | chingola
# Processing Record 33 of Set 8 | sarmanovo
# Processing Record 34 of Set 8 | palana
# City not found. Skipping...
# Processing Record 35 of Set 8 | chililabombwe
# Processing Record 36 of Set 8 | kawhia
# Processing Record 37 of Set 8 | champerico
# Processing Record 38 of Set 8 | katsuura
# Processing Record 39 of Set 8 | banjar
# Processing Record 40 of Set 8 | moerai
# Processing Record 41 of Set 8 | tevaitoa
# Processing Record 42 of Set 8 | antsohihy
# Processing Record 43 of Set 8 | smithers
# Processing Record 44 of Set 8 | marzuq
# Processing Record 45 of Set 8 | inhambane
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | tazmalt
# Processing Record 49 of Set 8 | hiriyur
# Processing Record 1 of Set 9 | san andres
# Processing Record 2 of Set 9 | utrecht
# Processing Record 3 of Set 9 | ushibuka
# Processing Record 4 of Set 9 | gat
# Processing Record 5 of Set 9 | flinders
# Processing Record 6 of Set 9 | avera
# Processing Record 7 of Set 9 | kiama
# Processing Record 8 of Set 9 | vila
# Processing Record 9 of Set 9 | pyinmana
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | shingu
# Processing Record 12 of Set 9 | olga
# Processing Record 13 of Set 9 | nyurba
# Processing Record 14 of Set 9 | flin flon
# Processing Record 15 of Set 9 | ukiah
# Processing Record 16 of Set 9 | turukhansk
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | zabol
# Processing Record 19 of Set 9 | mmathubudukwane
# Processing Record 20 of Set 9 | gari
# Processing Record 21 of Set 9 | upington
# Processing Record 22 of Set 9 | myitkyina
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | boshan
# City not found. Skipping...
# Processing Record 25 of Set 9 | nizza monferrato
# Processing Record 26 of Set 9 | castlerea
# Processing Record 27 of Set 9 | sinfra
# Processing Record 28 of Set 9 | kovur
# Processing Record 29 of Set 9 | mount gambier
# Processing Record 30 of Set 9 | loubomo
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | srednekolymsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | borogontsy
# Processing Record 34 of Set 9 | kupang
# Processing Record 35 of Set 9 | hasaki
# Processing Record 36 of Set 9 | zhanaozen
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | piopio
# Processing Record 39 of Set 9 | barra do bugres
# Processing Record 40 of Set 9 | key west
# City not found. Skipping...
# Processing Record 41 of Set 9 | odweyne
# Processing Record 42 of Set 9 | takab
# Processing Record 43 of Set 9 | ellisras
# Processing Record 44 of Set 9 | bardiyah
# Processing Record 45 of Set 9 | guerrero negro
# Processing Record 46 of Set 9 | newport
# Processing Record 47 of Set 9 | port moresby
# Processing Record 48 of Set 9 | yarmouth
# Processing Record 49 of Set 9 | orlik
# Processing Record 1 of Set 10 | collie
# Processing Record 2 of Set 10 | mount darwin
# Processing Record 3 of Set 10 | gornopravdinsk
# Processing Record 4 of Set 10 | mys shmidta
# Processing Record 5 of Set 10 | bereda
# Processing Record 6 of Set 10 | zavetnoye
# Processing Record 7 of Set 10 | amaraji
# Processing Record 8 of Set 10 | whitehaven
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | yashkul
# City not found. Skipping...
# Processing Record 12 of Set 10 | morro bay
# Processing Record 13 of Set 10 | zeya
# Processing Record 14 of Set 10 | novobelokatay
# Processing Record 15 of Set 10 | dingle
# Processing Record 16 of Set 10 | okhotsk
# City not found. Skipping...
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | hami
# Processing Record 19 of Set 10 | wajima
# Processing Record 20 of Set 10 | beloye
# Processing Record 21 of Set 10 | riyadh
# Processing Record 22 of Set 10 | khani
# Processing Record 23 of Set 10 | ternate
# Processing Record 24 of Set 10 | lasa
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | ust-tsilma
# Processing Record 27 of Set 10 | vryburg
# Processing Record 28 of Set 10 | sabang
# City not found. Skipping...
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | ribas do rio pardo
# Processing Record 31 of Set 10 | blagnac
# Processing Record 32 of Set 10 | kilindoni
# Processing Record 33 of Set 10 | dhar
# Processing Record 34 of Set 10 | romanovka
# Processing Record 35 of Set 10 | nizhniy kuranakh
# Processing Record 36 of Set 10 | khovu-aksy
# Processing Record 37 of Set 10 | lithgow
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | vardo
# Processing Record 40 of Set 10 | alanya
# City not found. Skipping...
# Processing Record 41 of Set 10 | bintulu
# City not found. Skipping...
# Processing Record 42 of Set 10 | valle hermoso
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | zhangye
# Processing Record 45 of Set 10 | kambam
# Processing Record 46 of Set 10 | manono
# City not found. Skipping...
# Processing Record 47 of Set 10 | san jose
# Processing Record 48 of Set 10 | radcliff
# Processing Record 49 of Set 10 | molina
# Processing Record 1 of Set 11 | kuvshinovo
# Processing Record 2 of Set 11 | numan
# Processing Record 3 of Set 11 | san rafael
# Processing Record 4 of Set 11 | waipawa
# Processing Record 5 of Set 11 | salta
# Processing Record 6 of Set 11 | kachug
# Processing Record 7 of Set 11 | coahuayana
# Processing Record 8 of Set 11 | shenjiamen
# Processing Record 9 of Set 11 | grants pass
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 11 | kenitra
# Processing Record 11 of Set 11 | petrozavodsk
# Processing Record 12 of Set 11 | malatya
# Processing Record 13 of Set 11 | culaman
# Processing Record 14 of Set 11 | ban tak
# Processing Record 15 of Set 11 | nsanje
# Processing Record 16 of Set 11 | pevek
# Processing Record 17 of Set 11 | tura
# Processing Record 18 of Set 11 | nakskov
# Processing Record 19 of Set 11 | hofn
# Processing Record 20 of Set 11 | anadyr
# Processing Record 21 of Set 11 | taywarah
# Processing Record 22 of Set 11 | jega
# City not found. Skipping...
# Processing Record 23 of Set 11 | oranjemund
# Processing Record 24 of Set 11 | tezu
# Processing Record 25 of Set 11 | juli
# Processing Record 26 of Set 11 | russell
# ------------------------------
# Your Data Has Been Retrieved
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for establishing dataframe
weather_dict = {
    "City": city_two,
    "Cloudiness": cloudiness,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}

# Create a DataFrame from the dictionary
weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 0        georgetown          20      MY  1636931432        93   5.4112
# 1          zhigansk          61      RU  1636931432        99  66.7697
# 2            hobart          75      AU  1636931385        60 -42.8794
# 3          westport          20      US  1636931432        65  41.1415
# 4    saint-philippe          54      RE  1636931433        80 -21.3585
# ..              ...         ...     ...         ...       ...      ...
# 511            jega         100      NG  1636931593        19  12.2175
# 512      oranjemund          11      NA  1636931594        83 -28.5500
# 513            tezu           9      IN  1636931594        50  27.9167
# 514            juli          85      PE  1636931594        57 -16.2167
# 515         russell           1      US  1636931595        72  32.3502
#
#           Lng  Max Temp  Wind Speed
# 0    100.3354     78.89        0.00
# 1    123.3711    -25.29        7.00
# 2    147.3294     51.03        4.00
# 3    -73.3579     48.79        1.01
# 4     55.7679     74.79       13.15
# ..        ...       ...         ...
# 511    4.3792     81.09        3.78
# 512   16.4333     62.01       10.49
# 513   96.1667     60.96        3.60
# 514  -69.4500     52.45        5.35
# 515  -85.1999     55.00        0.00
#
# [516 rows x 9 columns]

# %%
# Note to avoid any issues later, use encoding="utf-8"
weather_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Remove cities where the humidity is >100%
weather_df.describe()

###### There are no cities that have humidity over 100% ########
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  516.000000  5.160000e+02  516.000000  516.000000  516.000000
# mean    60.420543  1.636932e+09   73.323643   22.482059   27.027767
# std     39.050720  6.540658e+01   20.999628   32.898102   86.990820
# min      0.000000  1.636931e+09   12.000000  -54.800000 -175.200000
# 25%     20.000000  1.636931e+09   63.000000   -5.588100  -36.004800
# 50%     75.000000  1.636932e+09   78.000000   29.862150   29.763800
# 75%     98.000000  1.636932e+09   89.000000   50.493200  100.483575
# max    100.000000  1.636932e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  516.000000  516.000000
# mean    53.326570    6.954787
# std     25.363419    5.468549
# min    -25.290000    0.000000
# 25%     35.785000    3.050000
# 50%     60.125000    5.750000
# 75%     74.540000    9.070000
# max     96.400000   40.090000

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_weather_df = weather_df.loc[weather_df["Humidity"] < 100, [
    "City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date" ]]
clean_weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      georgetown   5.4112  100.3354     78.89        93          20
# 1        zhigansk  66.7697  123.3711    -25.29        99          61
# 2          hobart -42.8794  147.3294     51.03        60          75
# 3        westport  41.1415  -73.3579     48.79        65          20
# 4  saint-philippe -21.3585   55.7679     74.79        80          54
#
#    Wind Speed Country        Date
# 0        0.00      MY  1636931432
# 1        7.00      RU  1636931432
# 2        4.00      AU  1636931385
# 3        1.01      US  1636931432
# 4       13.15      RE  1636931433

# %%
clean_weather_df.info()

# Drop rows missing data
weather_data_no_null = clean_weather_df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503 entries, 0 to 515
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        503 non-null    object
#  1   Lat         503 non-null    float64
#  2   Lng         503 non-null    float64
#  3   Max Temp    503 non-null    float64
#  4   Humidity    503 non-null    int64
#  5   Cloudiness  503 non-null    int64
#  6   Wind Speed  503 non-null    float64
#  7   Country     503 non-null    object
#  8   Date        503 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.3+ KB

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (01/07/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# northern_hem = weather_data_no_null['Lat'] >= 1
# southern_hem = weather_data_no_null['Lat'] < 1

northern_hem_df = weather_df.loc[weather_df["Lat"] >= 0, [
    "City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date" ]]
northern_hem_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     georgetown   5.4112  100.3354     78.89        93          20
# 1       zhigansk  66.7697  123.3711    -25.29        99          61
# 3       westport  41.1415  -73.3579     48.79        65          20
# 5  mar del plata  43.4002   -4.0094     57.02        86          75
# 6        talnakh  69.4865   88.3972    -12.01        99          89
#
#    Wind Speed Country        Date
# 0        0.00      MY  1636931432
# 1        7.00      RU  1636931432
# 3        1.01      US  1636931432
# 5        3.00      ES  1636931433
# 6        3.20      RU  1636931433

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_hem_df["Lat"]
y_values = northern_hem_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere - Max Temp')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_hem_df['Lat']
y_values = southern_hem_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere - Max Temp')
plt.show()

# %% [markdown]
# The linear regression is showing there is a strong correlation between max temp and latitude. The closer you get to the equator (0), the higher the max temp will be.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_df["Lat"]
y_values = northern_hem_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere - Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.13445123567190692

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_df['Lat']
y_values = southern_hem_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere - Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.16110663300137512

# %% [markdown]
# Here the linear regression is comparing the humidity % compared to the latitude. It appears the further north you go the more humid it becomes!

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hem_df["Lat"]
y_values = northern_hem_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere - Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.027048337518821835

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hem_df['Lat']
y_values = southern_hem_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere - Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.051743622216985426

# %% [markdown]
# Here the linear regression is comparing the cloudiness % and latitude. It looks like there is a slight positive relationship between cloudiness and latitude. The further north a person goes, the higher the cloudiness % appears to be.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hem_df["Lat"]
y_values = northern_hem_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Northern Hemisphere - Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.059975373097747746

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hem_df['Lat']
y_values = southern_hem_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')
plt.xlabel('Latitude')
plt.ylabel('Southern Hemisphere - Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10600346418445901

# %% [markdown]
# The linear regression is looking for a relationship between wind speed and latitude. It does not appear there is any relationship between wind speed and latitude.
